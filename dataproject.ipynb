# %% [markdown]
# # My first data science project

# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
player = "Roger Federer" 
data = pd.read_csv('https://github.com/ipython-books/'
                 'cookbook-2nd-data/blob/master/'
                 'federer.csv?raw=true',
                 parse_dates=['start date'],
                 dayfirst=True)
data.head()
# Out:
#    year           tournament start date type        surface      draw  \
# 0  1998   Basel, Switzerland 1998-10-05   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland 1998-08-24   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
# We want to add a collum if player had won or not 

data["win"] = data["winner"] == player
data["win"].tail()
# Out:
# 1174    False
# 1175     True
# 1176     True
# 1177     True
# 1178    False
# Name: win, dtype: bool

# %%
data.head()
# Out:
#    year           tournament start date type        surface      draw  \
# 0  1998   Basel, Switzerland 1998-10-05   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland 1998-08-24   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 break points converted won player2 break points converted total  \
# 0                                4.0                                  8.0
# ...

# %%
# making a variabel named won where we calculate the persent of rogers win 
won = 100*data["win"].mean()
print (f"{player} has won {won:.0f}% of his matches")
# Out:
# Roger Federer has won 82% of his matches

# %%
date = data["start date"]

# %%
data["db1faults"] = data["player1 double faults"] / data["player1 total points total"]

# %%
data.head()
# Out:
#    year           tournament start date type        surface      draw  \
# 0  1998   Basel, Switzerland 1998-10-05   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France 1998-09-28   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland 1998-08-24   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 break points converted total player2 return games played  \
# 0                                  8.0                         8.0
# ...

# %%
#cheeking the data 
data["db1faults"].tail()
# Out:
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: db1faults, dtype: float64

# %%
data["db1faults"].describe()
# Out:
# count    1027.000000
# mean        0.012129
# std         0.010797
# min         0.000000
# 25%         0.004444
# 50%         0.010000
# 75%         0.018108
# max         0.060606
# Name: db1faults, dtype: float64

# %%
#Using the group by function to calculate the proportoion of wins by surface
data.groupby("surface")["win"].mean()
# Out:
# surface
# Indoor: Carpet    0.736842
# Indoor: Clay      0.833333
# Indoor: Hard      0.836283
# Outdoor: Clay     0.779116
# Outdoor: Grass    0.871429
# Outdoor: Hard     0.842324
# Name: win, dtype: float64

# %%
gb = data.groupby("year")
